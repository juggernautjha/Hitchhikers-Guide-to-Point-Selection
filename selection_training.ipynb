# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf

import random, glob, os
import numpy as np

from pydub import AudioSegment
from pydub import effects
from utils.refactored_common import *
# from utils.refactored_common import unision_shuffled_copies
from tqdm.notebook import tqdm
import pydub
import librosa
try :
    from keras.utils import Sequence #   sequence =  keras.utils.Sequence
except:
    from keras.utils.all_utils import Sequence


# import tensorflow_io as tfio

import soundfile as sf
import audioflux
from scipy import signal

import matplotlib.pyplot as plt

# %%
from generators import base_generator_audio as BASE
from  curricula import selection
from audio_models import base_cnn, transformer_classifier

# %%
class rho_generator_audio(BASE.BaseClassificationGenerator):
    def __init__(self, param, base_dir : str, batch_size : int = 16, shuffle : bool = True, gentype : str = 'train', return_spec : bool = False, return_fft : bool = False, ext : str = 'flac', 
                 selector = None, irred_model : tf.keras.Model = None, target_model_path : str = '', epoch_cutoff : int = 3, minibatch_size : float = 0.6, loss : tf.keras.losses.Loss = tf.keras.losses.categorical_crossentropy):
        super().__init__(param, base_dir, batch_size, shuffle, gentype, return_spec, return_fft, ext)
        self.selector = selector
        self.irred_model = irred_model
        self.target_model_path = target_model_path
        self.epoch_cutoff = epoch_cutoff
        self.minibatch_size = minibatch_size
        self.loss = loss

        self.select_func = None;
        self.target_model = None

        self.cache = None

        #start rho_selection after epoch_cutoff
        #! selector takes in pretrained model, target model, and returns a list of indices


    def on_epoch_end(self):
        self.epoch_cutoff = self.epoch_cutoff - 1 if self.epoch_cutoff > 0 else 0
        if self.selector is not None and self.epoch_cutoff <= 0:
            self.target_model = tf.keras.models.load_model(self.target_model_path)
            self.target_model.compile(optimizer = 'adam', loss = self.loss, metrics = ['accuracy'])

            self.select_func = self.selector(self.irred_model, self.target_model, self.minibatch_size)
        print(self.cache)

    def __getitem__(self, index):
        a, b = super().__getitem__(index)
        
        if self.selector is not None and self.epoch_cutoff <= 0:
            indices = self.select_func(a, b)
            a = a[indices]
            b = b[indices]
        self.cache = (a.shape, b.shape)
        return a, b

# %% [markdown]
# ### RHO Training

# %%
run_name = "audio_mnist__CNN__Transformer__rho_selection"
irred_chkpt = "checkpoints/audio_mnist_losses_spectrogram.keras"
target_chkpt = "checkpoints/audio_mnist_transformer.keras"
width = 25
height = 128
num_classes = 10

param = yaml_load("cfg.yaml")

# %%
model = transformer_classifier.BaseTransformerClassifier(width, height, num_classes)
checkpoint_filepath = target_chkpt
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='accuracy',
    mode='max',
    save_best_only=True)

import datetime
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=f"logs/{target_chkpt.split('.')[0]}_{datetime.datetime.now().strftime('%Y%m%d-%H%M%S')}", histogram_freq=1)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_76"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 25, 128)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 25, 16)    │    262,160 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_10          │ (None, 25, 16)    │          0 │ conv1d_15[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ filter_e0 (Conv1D)  │ (None, 13, 32)    │      4,128 │ reshape_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gate_e0 (Conv1D)    │ (None, 13, 32)    │      4,128 │ reshape_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mult_e0 (Multiply)  │ (None, 13, 32)    │          0 │ filter_e0[0][0],  │
# │                     │                   │            │ gate_e0[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ trans_e0 (Conv1D)   │ (None, 13, 32)    │      1,056 │ mult_e0[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 32)    │        128 │ trans_e0[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 13, 32)    │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ filter_e1 (Conv1D)  │ (None, 4, 4)      │      1,028 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gate_e1 (Conv1D)    │ (None, 4, 4)      │      1,028 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mult_e1 (Multiply)  │ (None, 4, 4)      │          0 │ filter_e1[0][0],  │
# │                     │                   │            │ gate_e1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ trans_e1 (Conv1D)   │ (None, 4, 4)      │         20 │ mult_e1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4)      │         16 │ trans_e1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 4, 4)      │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 4)      │          8 │ dropout_31[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 4)      │     19,460 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 4, 4)      │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 4, 4)      │          0 │ dropout_33[0][0], │
# │                     │                   │            │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 4)      │          8 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 4, 8)      │         40 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 4, 8)      │          0 │ conv1d_16[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 4, 4)      │         36 │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 4, 4)      │          0 │ conv1d_17[0][0],  │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_11          │ (None, 16, 1)     │          0 │ add_11[0][0]      │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ reshape_11[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 128)       │      2,176 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 128)       │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10)        │      1,290 │ dropout_35[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 296,710 (1.13 MB)
#  Trainable params: 296,638 (1.13 MB)
#  Non-trainable params: 72 (288.00 B)

# %%
import json

def to_json(obj):
    return json.dumps(obj, default=lambda obj: obj.__dict__)

# %%
import jsonpickle
json_string = jsonpickle.encode(rho_generator.__dict__)

# %%
rho_generator.__dict__
# Out:
# {'ext': 'wav',
#  'base_dir': 'data/mnist/',
#  'batch_size': 32,
#  'shuffle': True,
#  'gentype': 'train',
#  'classes': ['5_dgt',
#   '6_dgt',
#   '1_dgt',
#   '2_dgt',
#   '3_dgt',
#   '7_dgt',
#   '4_dgt',
#   '0_dgt',
#   '8_dgt',
#   '9_dgt'],
#  'class_dict': {'5_dgt': 0,
#   '6_dgt': 1,
#   '1_dgt': 2,
#   '2_dgt': 3,
#   '3_dgt': 4,
#   '7_dgt': 5,
#   '4_dgt': 6,
#   '0_dgt': 7,
#   '8_dgt': 8,
#   '9_dgt': 9},
#  'files': [('5_dgt', 'data/mnist//train/5_dgt/5_08_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_22_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_57_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_47_2.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_48.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_18_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_04_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_32_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_54_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_52_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_39.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_7.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_46_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_34.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_14_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_28.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_21_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_56_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_06_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_44_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_07_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_20_8.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_30_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_39_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_50_1.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_10_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_49_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_23.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_12.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_21.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_02_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_27_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_24_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_9.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_29_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_34_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_03_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_05_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_35_0.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_26_49.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_11_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_40.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_31_42.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_59_4.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_37_29.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_25.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_5.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_30.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_33_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_25_20.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_23_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_17_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_01_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_31.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_11.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_45.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_41_46.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_48_43.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_43_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_18.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_41.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_58_37.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_10.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_36_38.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_15_13.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_35.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_44.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_38_15.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_47.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_09_6.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_17.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_16_32.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_19_3.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_42_14.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_60_19.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_40_22.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_51_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_12_33.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_13_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_08_16.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_28_26.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_55_27.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_36.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_53_24.wav'),
#   ('5_dgt', 'data/mnist//train/5_dgt/5_45_43.wav'),
#   ...],
#  'param': {'feature': {'raw_mode': 0,
#    'n_mels': 128,
#    'frames': -1,
#    'n_fft': 4096,
#    'hop_length': 1200,
#    'win_length': 4096,
#    'steps': 1,
#    'flatten': False,
#    'incNG': 0,
#    'return_label': False,
#    'normalize': False,
#    'Fs': 48000,
#    'duration': 10,
#    'includePre': False,
#    'ignLimit': 128,
#    'enable_kmeans': False,
#    'log': True,
#    'librosa': False,
#    'pcen_norm': False,
#    'pydub_norm': False,
#    'mel_norm': False,
#    'threshold': 0.9,
#    'window': 'gauss',
#    'window_types': {'hann': 1,
#     'hamm': 2,
#     'blackman': 3,
#     'kaiser': 4,
#     'gauss': 8,
#     'tukey': 13}}},
#  'n_fft': 4096,
#  'hop_length': 1200,
#  'win_length': 4096,
#  'Fs_Multiple': 0.5,
#  'Fs': 48000,
#  'duration': 10,
#  'n_mels': 128,
#  'mel_length': 397,
#  'num_classes': 10,
#  'gen_mel': True,
#  'gen_stft': False,
#  'selector': curricula.selection.irreducible_loss_selector,
#  'irred_model': <Sequential name=sequential_1, built=True>,
#  'target_model_path': 'checkpoints/audio_mnist_transformer.keras',
#  'epoch_cutoff': 0,
#  'minibatch_size': 0.6,
#  'loss': 'categorical_crossentropy',
#  'select_func': <curricula.selection.irreducible_loss_selector at 0x7fec421de3d0>,
#  'target_model': <Functional name=functional_76, built=True>,
#  'cache': ((19, 25, 128), (19, 10)),
#  '_workers': 1,
#  '_use_multiprocessing': False,
#  '_max_queue_size': 10}

# %%
json.dumps()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_523566/1932078287.py in <module>
# ----> 1 json.dumps(rho_generator.__dict__)
#
# ~/.conda/envs/ravijas/lib/python3.9/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~/.conda/envs/ravijas/lib/python3.9/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~/.conda/envs/ravijas/lib/python3.9/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~/.conda/envs/ravijas/lib/python3.9/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type type is not JSON serializable

# %%
rho_generator = rho_generator_audio(
    param, "data/mnist/", batch_size=32, return_spec=True, ext = 'wav', selector=selection.irreducible_loss_selector, irred_model = tf.keras.models.load_model(irred_chkpt), target_model_path = target_chkpt, epoch_cutoff = 3, minibatch_size = 0.6, loss = 'categorical_crossentropy'
)

# %%
a, b = rho_generator.__getitem__(0)

# %%
model.fit(rho_generator, epochs=10, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/10
# /home/juggernautjha/.conda/envs/ravijas/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.1920 - loss: 2.1427((32, 25, 128), (32, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 68s 135ms/step - accuracy: 0.1922 - loss: 2.1422
# Epoch 2/10
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5498 - loss: 1.1648((32, 25, 128), (32, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 65s 137ms/step - accuracy: 0.5499 - loss: 1.1646
# Epoch 3/10
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7214 - loss: 0.7063((32, 25, 128), (32, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 62s 131ms/step - accuracy: 0.7215 - loss: 0.7062
# Epoch 4/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7701 - loss: 0.6133((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 83s 176ms/step - accuracy: 0.7701 - loss: 0.6131
# Epoch 5/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8410 - loss: 0.4196((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 80s 170ms/step - accuracy: 0.8409 - loss: 0.4197
# Epoch 6/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8665 - loss: 0.3513((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 82s 173ms/step - accuracy: 0.8665 - loss: 0.3512
# Epoch 7/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8733 - loss: 0.3485((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 74s 157ms/step - accuracy: 0.8734 - loss: 0.3484
# Epoch 8/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9056 - loss: 0.2667((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 81s 171ms/step - accuracy: 0.9056 - loss: 0.2668
# Epoch 9/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9057 - loss: 0.2581((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 64s 136ms/step - accuracy: 0.9057 - loss: 0.2580
# Epoch 10/10
# 467/468 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9258 - loss: 0.2047((19, 25, 128), (19, 10))
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 83s 176ms/step - accuracy: 0.9258 - loss: 0.2048
